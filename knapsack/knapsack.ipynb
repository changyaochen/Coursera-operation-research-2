# %%
# !python benchmark.py
# Out:
# 2021-12-09 22:32:54,999 [INFO] hello world!
# 2021-12-09 22:32:54,999 [INFO] Solving the knapsack problem with 10 items.
# 2021-12-09 22:32:55,000 [INFO] build_knapsack_problem took 1.349 ms to execute.
# 2021-12-09 22:32:55,001 [INFO] Use the cbc solver.
# 2021-12-09 22:32:55,014 [INFO] The optimal value is: 23.631003327837863
# 2021-12-09 22:32:55,014 [INFO] solve_pulp_problem took 13.384 ms to execute.
# 2021-12-09 22:32:55,014 [INFO] Use the gurobi solver.
# 2021-12-09 22:32:55,042 [INFO] The optimal value is: 23.631003326773182
# 2021-12-09 22:32:55,042 [INFO] solve_pulp_problem took 27.882 ms to execute.
# 2021-12-09 22:32:55,042 [INFO] Solving the knapsack problem with 31 items.
# 2021-12-09 22:32:55,045 [INFO] build_knapsack_problem took 2.607 ms to execute.
# 2021-12-09 22:32:55,045 [INFO] Use the cbc solver.
# 2021-12-09 22:32:55,063 [INFO] The optimal value is: 88.69126078030482
# 2021-12-09 22:32:55,063 [INFO] solve_pulp_problem took 18.044 ms to execute.
# ...
